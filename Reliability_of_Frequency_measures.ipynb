# %% [markdown]
# ## # Reliability of Keyness measures
#
# Source of data: https://osf.io/r9atd

# %%
pip install pygal  #Installing pygal
# Out:
# Requirement already satisfied: pygal in /usr/local/lib/python3.10/dist-packages (3.0.4)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from pygal) (6.8.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->pygal) (3.17.0)

# %% [markdown]
# To display the chart within the Jupyter Notebook:

# %%
from IPython.display import display, HTML

base_html = """
<!DOCTYPE html>
<html>
  <head>
  <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
  <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
  </head>
  <body>
    <figure>
      {rendered_chart}
    </figure>
  </body>
</html>
"""

# %% [markdown]
# # Reliability of Keyness measures
# We import `pandas` and `pygal` and read in the csv-File. Printing out the table to check if it is ok:

# %%
import pandas as pd

# Pfad zu deiner Datei anpassen
file_path = "reliability.txt"

# Korrekte Trennzeichen angeben (Tabulator)
df = pd.read_csv(file_path, sep='\t')

# DataFrame anzeigen
df
# Out:
#                             metric type_short                   type  \
# 1        Likelihood ratio test (B)       3f_d   Frequency difference
# 2             Chi-squared test (B)       3f_d   Frequency difference
# 3                          BIC (B)       3f_d   Frequency difference
# 4                   Signed DKL (B)       3f_d   Frequency difference
# 5             TD-based LR test (T)       4d_d  Dispersion difference
# 6                    Rate ACAD (B)         1f              Frequency
# 7              Rate difference (B)       3f_d   Frequency difference
# 8                   Rate ratio (B)       3f_d   Frequency difference
# 9                     TD ratio (T)       4d_d  Dispersion difference
# 10  Wilcoxon rank sum test, PS (T)       3f_d   Frequency difference
# 11                      T-test (T)       3f_d   Frequency difference
# 12                   Rate ACAD (T)         1f              Frequency
# 13                  Rate ratio (T)       3f_d   Frequency difference
# 14             Rate difference (T)       3f_d   Frequency difference
# 15                              DP         2d             Dispersion
# 16                              DA         2d             Dispersion
# 17                               D         2d             Dispersion
# 18                            Sadj         2d             Dispersion
# 19                              D2         2d             Dispersion
# 20                              TD         2d             Dispersion
# 21                             DKL         2d             Dispersion
# 22                         DP diff       4d_d  Dispersion difference
# 23                         DA diff       4d_d  Dispersion difference
# 24                          D diff       4d_d  Dispersion difference
# 25                       Sadj diff       4d_d  Dispersion difference
# 26                         D2 diff       4d_d  Dispersion difference
# 27                         TD diff       4d_d  Dispersion difference
# 28                        DKL diff       4d_d  Dispersion difference
#
#     desc_inf  cor_ranks
# 1          2   0.813932
# 2          2   0.815383
# 3          2   0.813932
# 4          1   0.723501
# 5          2   0.808353
# 6          1   0.882807
# 7          1   0.903800
# 8          1   0.895928
# 9          1   0.902728
# 10         2   0.926907
# 11         2   0.810896
# 12         1   0.814418
# 13         1   0.779863
# 14         1   0.779788
# 15         1   0.879407
# 16         1   0.766766
# 17         1   0.525336
# 18         1   0.873878
# 19         1   0.707644
# 20         1   0.918097
# 21         1   0.832549
# 22         1   0.851257
# 23         1   0.686056
# 24         1   0.480982
# 25         1   0.847029
# 26         1   0.641238
# 27         1   0.924739
# 28         1   0.758050

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df['type'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df, x='cor_ranks', y='type', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %%
from plotnine import ggplot, aes, geom_point, theme, labs

# Create the scatterplot
scatter_plot = (ggplot(df, aes(x='cor_ranks', y='metric', color ='cor_ranks'))
                + geom_point()
              #  + theme(legend_position='right')
                + labs(x='cor ranks', y='Keyness measures'))

# Display the plot
print(scatter_plot)

# %%
import plotly.express as px

fig = px.scatter(df, x='cor_ranks', y='metric', color='cor_ranks',  text ='metric')
fig.update_traces(marker=dict(size=12),
                  selector=dict(mode='markers'))
fig.update_layout(title='Keyness measures - an overview ',
                  xaxis_title='Reliability (cf. Sönning 2022)',
                  yaxis_title='Keyness Measures'
                  )

fig.show()
fig.write_html("scatterplot_plotly.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6b7ec5ad-a4ef-48b0-9f06-47e966e77b6b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b7ec5ad-a4ef-48b0-9f06-47e966e77b6b")) {                    Plotly.newPlot(                        "6b7ec5ad-a4ef-48b0-9f06-47e966e77b6b",                        [{"hovertemplate":"cor_ranks=%{marker.color}\u003cbr\u003emetric=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[0.813932357650282,0.815382751539017,0.813932357650282,0.723501389382432,0.808352917767708,0.882807234207081,0.903800317712243,0.895927802705153,0.902728197308595,0.926907032705226,0.810896384863194,0.814418326511471,0.779862930728306,0.779788044765777,0.879407450325303,0.766766244288386,0.525336232881613,0.873878063117171,0.707643759308317,0.918097240297359,0.832549346611,0.851256706545624,0.686056289649288,0.480982011418364,0.847029045906084,0.64123751809406,0.924738599504461,0.758049517136129],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers+text","name":"","orientation":"h","showlegend":false,"text":["Likelihood ratio test (B)","Chi-squared test (B)","BIC (B)","Signed DKL (B)","TD-based LR test (T)","Rate ACAD (B)","Rate difference (B)","Rate ratio (B)","TD ratio (T)","Wilcoxon rank sum test, PS (T)","T-test (T)","Rate ACAD (T)","Rate ratio (T)","Rate difference (T)","DP","DA","D","Sadj","D2","TD","DKL","DP diff","DA diff","D diff","Sadj diff","D2 diff","TD diff","DKL diff"],"x":[0.813932357650282,0.815382751539017,0.813932357650282,0.723501389382432,0.808352917767708,0.882807234207081,0.903800317712243,0.895927802705153,0.902728197308595,0.926907032705226,0.810896384863194,0.814418326511471,0.779862930728306,0.779788044765777,0.879407450325303,0.766766244288386,0.525336232881613,0.873878063117171,0.707643759308317,0.918097240297359,0.832549346611,0.851256706545624,0.686056289649288,0.480982011418364,0.847029045906084,0.64123751809406,0.924738599504461,0.758049517136129],"xaxis":"x","y":["Likelihood ratio test (B)","Chi-squared test (B)","BIC (B)","Signed DKL (B)","TD-based LR test (T)","Rate ACAD (B)","Rate difference (B)","Rate ratio (B)","TD ratio (T)","Wilcoxon rank sum test, PS (T)","T-test (T)","Rate ACAD (T)","Rate ratio (T)","Rate difference (T)","DP","DA","D","Sadj","D2","TD","DKL","DP diff","DA diff","D diff","Sadj diff","D2 diff","TD diff","DKL diff"],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0," ...

# %%
pip install cairosvg
# Out:
# Collecting cairosvg
#   Downloading CairoSVG-2.7.1-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 1.7 MB/s eta 0:00:00
# Collecting cairocffi (from cairosvg)
#   Downloading cairocffi-1.6.1-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.1/75.1 kB 4.3 MB/s eta 0:00:00
# Collecting cssselect2 (from cairosvg)
#   Downloading cssselect2-0.7.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from cairosvg) (0.7.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from cairosvg) (9.4.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from cairosvg) (1.2.1)
# Requirement already satisfied: cffi>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from cairocffi->cairosvg) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from cssselect2->cairosvg) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.1.0->cairocffi->cairosvg) (2.21)
# Installing collected packages: cssselect2, cairocffi, cairosvg
# Successfully installed cairocffi-1.6.1 cairosvg-2.7.1 cssselect2-0.7.0

# %%
import pygal
from IPython.display import Image, display, HTML

# Create a bar chart
bar_chart = pygal.Bar()
bar_chart.legend_at_bottom = True
bar_chart.y_title = 'Reliability score'

# Loop through each metric and add bars to the chart
for metric in ['Likelihood ratio test (B)', 'Chi-squared test (B)', 'Wilcoxon rank sum test, PS (T)', 'T-test (T)', 'Rate ratio (B)', 'TD-based LR test (T)']:
    # Filter the dataframe for the current metric
    df_filtered = df[df['metric'] == metric]

    # Create a list of tuples with x (desc_inf) and y (cor_ranks) values for the current metric
    data = [(row['desc_inf'], row['cor_ranks']) for _, row in df_filtered.iterrows()]

    # Sort the data by 'desc_inf' for better presentation
    data.sort(key=lambda x: x[0])

    # Unzip the data to separate 'desc_inf' and 'cor_ranks'
    desc_inf, cor_ranks = zip(*data)

    # Add the bars to the bar chart with a label for the series
    bar_chart.add(metric, cor_ranks)

# Save the bar chart to a PNG file
chart_filename_png = 'bar_chart.png'
bar_chart.render_to_png(chart_filename_png)

# Display the chart in the notebook
display(Image(filename=chart_filename_png))

# %%
import pygal
from pygal.style import LightColorizedStyle as LCS, LightenStyle as LS
from IPython.display import HTML

# Check if 'cor_ranks' column contains numeric data
if not pd.api.types.is_numeric_dtype(df['cor_ranks']):
    raise ValueError("Column 'cor_ranks' must contain numeric data for a gauge chart.")

# List of specified metrics
selected_metrics = ['Likelihood ratio test (B)', 'Chi-squared test (B)', 'Wilcoxon rank sum test, PS (T)', 'T-test (T)', 'Rate ratio (B)', 'TD-based LR test (T)']

# Create a gauge chart
gauge_chart = pygal.Gauge(human_readable=True)

# Loop through each specified metric and add data points to the gauge chart
for metric in selected_metrics:
    # Filter the dataframe for the current metric
    filtered_data = df[df['metric'] == metric]

    # Calculate the average 'cor_ranks' value for the current metric
    avg_cor_ranks = filtered_data['cor_ranks'].mean()

    # Add the data point to the gauge chart with the metric as the label
    gauge_chart.add(metric, [{"value": avg_cor_ranks * 100}])

# Save the gauge chart to a PNG file
chart_filename_png = 'gauge_chart_selected_metrics.png'
gauge_chart.render_to_png(chart_filename_png)

# Display the gauge chart in the notebook
display(HTML(base_html.format(rendered_chart=gauge_chart.render(is_unicode=True))))

# Optional: Display the saved PNG file
from IPython.display import Image
display(Image(filename=chart_filename_png))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-395040cc-dc76-40b9-a741-dfbaee9adae7" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 3.0.4 (lxml) ©Kozea 2012-2016 on 2023-12-05--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-395040cc-dc76-40b9-a741-dfbaee9adae7{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-395040cc-dc76-40b9-a741-dfbaee9adae7{background-color:rgba(249,249,249,1)}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 path,#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 line,#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 rect,#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .graph{fill:rgba(0,0,0,.87)}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 text.no_data{fill:rgba(0,0,0,1)}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .title{fill:rgba(0,0,0,1)}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .axis .line{stroke:rgba(0,0,0,1)}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .axis text.major{fill:rgba(0,0,0,1)}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .axis.y .guides:hover .guide.line,#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .line-graph .axis.x .guides:hover .guide.line,#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .reactive{fill-opacity:.7;stroke-opacity:.8;stroke-width:1}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .ci{stroke:rgba(0,0,0,.87)}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .reactive.active,#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .ci .reactive.active{stroke-width:1.5}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .series text{fill:rgba(0,0,0,1)}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .tooltip .value{font-size:1.5em}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .bound{font-size:.5em}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .color-0,#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .color-1,#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .color-2,#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .color-2 a:visited{stroke:#009688;fill:#009688}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .color-3,#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .color-3 a:visited{stroke:#FFC107;fill:#FFC107}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .color-4,#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 . ...
# #chart-395040cc-dc76-40b9-a741-dfbaee9adae7 text.no_data{text-anchor:middle}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .guide.line{fill:none}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .centered{text-anchor:middle}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .title{text-anchor:middle}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .legends .legend text{fill-opacity:1}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .axis.x text{text-anchor:middle}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .axis.y text{text-anchor:end}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .axis.y text[transform].backwards{text-anchor:start}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .axis.y2 text{text-anchor:start}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .axis.y2 text[transform].backwards{text-anchor:end}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .axis .guide.line{stroke-dasharray:4,4;stroke:black}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .axis .major.guide.line{stroke-dasharray:6,6;stroke:black}#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .horizontal .axis.y .guide.line,#chart-395040cc-dc76-40b9-a741-dfbaee9adae7 .horizontal .axis.y2 .guide.line,#chart-395040cc-dc76-40b9-a741-dfbaee9adae7

# %%
import pygal
from pygal.style import LightColorizedStyle as LCS, LightenStyle as LS
from IPython.display import HTML

# Check if 'cor_ranks' column contains numeric data
if not pd.api.types.is_numeric_dtype(df['cor_ranks']):
    raise ValueError("Column 'cor_ranks' must contain numeric data for a gauge chart.")

# List of specific metrics
selected_metrics = ['Likelihood ratio test (B)', 'Chi-squared test (B)', 'Wilcoxon rank sum test, PS (T)', 'T-test (T)']

# Filter the DataFrame for the selected metrics
df_selected_metrics = df[df['metric'].isin(selected_metrics)]

# Calculate mean cor_ranks per type for the selected metrics
mean_by_type_selected_metrics = df_selected_metrics.groupby('metric')['cor_ranks'].mean()

# Create a SolidGauge chart
gauge = pygal.SolidGauge(inner_radius=0.70)
[gauge.add(type_, [{"value": mean * 100}]) for type_, mean in mean_by_type_selected_metrics.iteritems()]

# Save the SolidGauge chart to a PNG file
chart_filename_png = 'gauge_chart_selected_metrics.png'
gauge.render_to_png(chart_filename_png)

# Display the SolidGauge chart in the notebook
display(HTML(gauge.render(is_unicode=True)))

# Optional: Display the saved PNG file
from IPython.display import Image
display(Image(filename=chart_filename_png))
# Out:
# <ipython-input-87-b9726555bd7d>:20: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 3.0.4 (lxml) ©Kozea 2012-2016 on 2023-12-05--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><path id="valuePath-153.0140.0" d="M153.000000 36.680000 A103.320000 103.320000 0 1 1 152.998967 36.680000"/><path id="valuePath-459.0140.0" d="M459.000000 36.680000 A103.320000 103.320000 0 1 1 458.998967 36.680000"/><path id="valuePath-153.0420.0" d="M153.000000 316.680000 A103.320000 103.320000 0 1 1 152.998967 316.680000"/><path id="valuePath-459.0420.0" d="M459.000000 316.680000 A103.320000 103.320000 0 1 1 458.998967 316.680000"/><style type="text/css">#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7{background-color:rgba(249,249,249,1)}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 path,#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 line,#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 rect,#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .graph{fill:rgba(0,0,0,.87)}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 text.no_data{fill:rgba(0,0,0,1)}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .title{fill:rgba(0,0,0,1)}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .axis .line{stroke:rgba(0,0,0,1)}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .axis text.major{fill:rgba(0,0,0,1)}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .axis.y .guides:hover .guide.line,#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .line-graph .axis.x .guides:hover .guide.line,#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .reactive{fill-opacity:.7;stroke-opacity:.8;stroke-width:1}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .ci{stroke:rgba(0,0,0,.87)}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .reactive.active,#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .ci .reactive.active{stroke-width:1.5}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .series text{fill:rgba(0,0,0,1)}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .tooltip .value{font-size:1.5em}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .bound{font-size:.5em}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .color-0,#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .color-1,#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .color-2,#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .color-2 a:visited{stroke:#009688;fill:#009688}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .color-3,#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .color-3 a:visited{stroke:#FFC107;fill:#FFC107}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .text-overlay .color-0 text{fill:black}#chart-74b29c2d ...
# #chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 text.no_data{text-anchor:middle}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .guide.line{fill:none}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .centered{text-anchor:middle}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .title{text-anchor:middle}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .legends .legend text{fill-opacity:1}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .axis.x text{text-anchor:middle}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .axis.y text{text-anchor:end}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .axis.y text[transform].backwards{text-anchor:start}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .axis.y2 text{text-anchor:start}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .axis.y2 text[transform].backwards{text-anchor:end}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .axis .guide.line{stroke-dasharray:4,4;stroke:black}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .axis .major.guide.line{stroke-dasharray:6,6;stroke:black}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .horizontal .axis.y .guide.line,#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .horizontal .axis.y2 .guide.line,#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .vertical .axis.x .guide.line{opacity:0}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .horizontal .axis.always_show .guide.line,#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-74b29c2d-ea53-432a-bf3c-6e6458e4b6a7 .axis.y .guides:hover .guide.

# %%
import pygal
from pygal.style import LightColorizedStyle as LCS, LightenStyle as LS
from IPython.display import HTML

# Assuming df is the DataFrame with the required columns

# Check if 'cor_ranks' column contains numeric data
if not pd.api.types.is_numeric_dtype(df['cor_ranks']):
    raise ValueError("Column 'cor_ranks' must contain numeric data for a gauge chart.")

# Filter the DataFrame for 'type' values 'Dispersion' or 'Frequency'
df_filtered_types = df[df['type'].isin(['Dispersion', 'Frequency'])]

# Calculate mean cor_ranks per type for the selected types
mean_by_type_filtered = df_filtered_types.groupby('type')['cor_ranks'].mean()

# Create a SolidGauge chart
gauge = pygal.SolidGauge(inner_radius=0.70)
[gauge.add(type_, [{"value": mean * 100}]) for type_, mean in mean_by_type_filtered.iteritems()]

# Save the SolidGauge chart to a PNG file
chart_filename_png = 'gauge_chart_filtered_types.png'
gauge.render_to_png(chart_filename_png)

# Display the SolidGauge chart in the notebook
display(HTML(gauge.render(is_unicode=True)))

# Optional: Display the saved PNG file
from IPython.display import Image
display(Image(filename=chart_filename_png))
# Out:
# <ipython-input-86-03908afaef72>:19: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-c444ee03-a71f-481e-802e-4f27bad8eb64" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 3.0.4 (lxml) ©Kozea 2012-2016 on 2023-12-05--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><path id="valuePath-327.0140.0" d="M327.000000 36.680000 A103.320000 103.320000 0 1 1 326.998967 36.680000"/><path id="valuePath-327.0420.0" d="M327.000000 316.680000 A103.320000 103.320000 0 1 1 326.998967 316.680000"/><style type="text/css">#chart-c444ee03-a71f-481e-802e-4f27bad8eb64{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-c444ee03-a71f-481e-802e-4f27bad8eb64{background-color:rgba(249,249,249,1)}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 path,#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 line,#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 rect,#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .graph{fill:rgba(0,0,0,.87)}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 text.no_data{fill:rgba(0,0,0,1)}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .title{fill:rgba(0,0,0,1)}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .axis .line{stroke:rgba(0,0,0,1)}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .axis text.major{fill:rgba(0,0,0,1)}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .axis.y .guides:hover .guide.line,#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .line-graph .axis.x .guides:hover .guide.line,#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .reactive{fill-opacity:.7;stroke-opacity:.8;stroke-width:1}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .ci{stroke:rgba(0,0,0,.87)}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .reactive.active,#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .ci .reactive.active{stroke-width:1.5}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .series text{fill:rgba(0,0,0,1)}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .tooltip .value{font-size:1.5em}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .bound{font-size:.5em}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .color-0,#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .color-1,#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .text-overlay .color-0 text{fill:black}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .text-overlay .color-1 text{fill:black}
# #chart-c444ee03-a71f-481e-802e-4f27bad8eb64 text.no_data{text-anchor:middle}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .guide.line{fill:none}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .centered{text-anchor:middle}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .title{text-anchor:middle}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .legends .legend text{fill-opacity:1}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .axis.x text{text-anchor:middle}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .axis.y text{text-anchor:end}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .axis.y text[transform].backwards{text-anchor:start}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .axis.y2 text{text-anchor:start}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .axis.y2 text[transform].backwards{text-anchor:end}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .axis .guide.line{stroke-dasharray:4,4;stroke:black}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .axis .major.guide.line{stroke-dasharray:6,6;stroke:black}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .horizontal .axis.y .guide.line,#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .horizontal .axis.y2 .guide.line,#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .vertical .axis.x .guide.line{opacity:0}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .horizontal .axis.always_show .guide.line,#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .axis.y .guides:hover .guide.line,#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .axis.y2 .guides:hover .guide.line,#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .axis.x .guides:hover .guide.line{opacity:1}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .axis .guides:hover text{opacity:1}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .nofill{fill:none}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .subtle-fill{fill-opacity:.2}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .dot{stroke-width:1px;fill-opacity:1;stroke-opacity:1}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .dot.active{stroke-width:5px}#chart-c444ee03-a71f-481e-802e-4f27bad8eb64 .dot.negative{fill:transparent}#chart-c444ee03-a71f-481e-802e-4f27bad8eb6

# %% [markdown]
# References
#
# * https://feststelltaste.github.io/software-analytics/notebooks/vis/experimental/pandas-pygal/effective_charting.html
# * http://www.pygal.org/en/stable/documentation/first_steps.html
# * https://programmer.ink/think/python-data-visualization-pygal-svg-csv-bar-line.html
# * https://opensource.com/article/20/6/pygal-python
